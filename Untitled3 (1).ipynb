# %%
# Сравниваем цены на букеты из 15 цветов по трём источникам:
#
#   1. megacvet24.ru/15-tsvetov  — готовые букеты, цены как есть
#   2. bbflowers.ru              — оптовый прайс поштучно, берём × 15
#                                  выборка по категориям чтобы захватить
#                                  разные ценовые сегменты
#   3. cvetochnay-baza.ru        — розничный каталог поштучно, тоже × 15
#                                  корзины и орхидеи убираем — они ломают картину
#
# Запуск: python parse_bouquets.py
# Нужно: requests, beautifulsoup4, pandas, matplotlib

import re
import sys
import time
import random

import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.rcParams["font.family"] = "DejaVu Sans"
plt.rcParams["axes.unicode_minus"] = False

UA = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "ru-RU,ru;q=0.9",
    "Accept": "text/html,application/xhtml+xml,*/*;q=0.8",
}

# bbflowers разбит по категориям — берём из каждой несколько позиций
# равномерно, чтобы не получился алфавитный срез одной цены
BB_CATS = {
    "/catalog/roza/":         4,
    "/catalog/hrizantema/":   3,
    "/catalog/tyulpan/":      3,
    "/catalog/pion/":         2,
    "/catalog/liliya/":       2,
    "/catalog/gerbera/":      2,
    "/catalog/alstromeriya/": 2,
    "/catalog/eustoma/":      2,
}

# на оптцвет корзины стоят по 4-12 тысяч — это не цветы поштучно,
# убираем их вместе с орхидеями и цимбидиумом (слишком редкие/дорогие)
SKIP_OPTCVET = {"корзина", "цимбидиум", "орхидея", "орхид"}
MAX_PER_PIECE = 600  # выше этого — что-то пошло не так


def fetch(url, pause=True):
    if pause:
        time.sleep(random.uniform(1.0, 2.0))
    s = requests.Session()
    s.headers.update(UA)
    r = s.get(url, timeout=15)
    if r.status_code != 200:
        print(f"    ! {r.status_code} на {url}")
        return None
    return BeautifulSoup(r.text, "html.parser")


def rub(x, _=None):
    return f"{int(x):,}".replace(",", "\u202f")


# ─── megacvet24 ───────────────────────────────────────────────────────────────
# Структура хорошо задокументирована schema.org-разметкой:
# div.list-product > meta[itemprop="price"] content="2799.00"
# Если meta нет — берём из span.list-product__price, предварительно
# вырезав вложенные теги скидки и старой цены

# Числительные в названиях — чтобы пересчитать цену на 15
NUM_WORDS = {
    "1": 1, "3": 3, "5": 5, "7": 7, "9": 9, "11": 11, "13": 13,
    "15": 15, "19": 19, "25": 25, "35": 35, "45": 45,
}

# Типы цветов — берём по 3 позиции каждого
FLOWER_TYPES = [
    ("роза",        "Роза"),
    ("гвоздик",     "Гвоздика"),
    ("пион",        "Пион"),
    ("гортензи",    "Гортензия"),
    ("лили",        "Лилия"),
    ("хризантем",   "Хризантема"),
    ("альстромери", "Альстромерия"),
    ("ирис",        "Ирис"),
    ("гербер",      "Гербера"),
    ("эустом",      "Эустома"),
    ("тюльпан",     "Тюльпан"),
    ("подсолнух",   "Подсолнух"),
    ("ромашк",      "Ромашка"),
    ("гладиол",     "Гладиолус"),
    ("гипсофил",    "Гипсофила"),
    ("сирен",       "Сирень"),
    ("ранункулюс",  "Ранункулюс"),
]
MAX_PER_TYPE = 3


def price_for_15(name, price):
    # Ищем число в начале: "19 Пионов...", "9 Роз..."
    m = re.match(r"^(\d+)\s+", name)
    if not m:
        return price
    count = int(m.group(1))
    if count == 15:
        return price
    if count == 0:
        return None
    return round(price / count * 15)


def scrape_megacvet():
    base = "https://megacvet24.ru/15-tsvetov/"
    print("\n[1] megacvet24.ru — все 18 страниц, по 3 позиции каждого типа")

    raw = []
    for page in range(1, 19):
        url = base if page == 1 else f"{base}?page={page}"
        soup = fetch(url)
        if not soup:
            break

        cards = soup.select("div.list-product")
        print(f"    стр. {page}: {len(cards)} карточек")
        if not cards:
            break

        for card in cards:
            name_el = card.select_one("a.list-product__name span") \
                   or card.select_one("a.list-product__name")
            name = name_el.get_text(strip=True) if name_el else ""

            price = None
            meta = card.select_one('meta[itemprop="price"]')
            if meta and meta.get("content"):
                try:
                    price = int(float(meta["content"]))
                except ValueError:
                    pass

            if not price:
                span = card.select_one("span.list-product__price")
                if span:
                    for junk in span.select("span"):
                        junk.decompose()
                    digits = re.sub(r"[^\d]", "", span.get_text())
                    if digits:
                        price = int(digits)

            if name and price and 200 <= price <= 500_000:
                raw.append({"name": name, "price": price})

        if not soup.select_one("a[rel='next'], a[class*='next'], .pagination__next"):
            break

    raw = list({(r["name"], r["price"]): r for r in raw}.values())
    print(f"    всего до фильтрации: {len(raw)}")

    # По 3 позиции каждого типа, цену пересчитываем на 15
    seen = {ftype: 0 for ftype, _ in FLOWER_TYPES}
    result = []

    for row in raw:
        name_low = row["name"].lower()
        for ftype, label in FLOWER_TYPES:
            if ftype not in name_low:
                continue
            if seen[ftype] >= MAX_PER_TYPE:
                break
            p15 = price_for_15(row["name"], row["price"])
            if p15 and 200 <= p15 <= 500_000:
                seen[ftype] += 1
                m = re.match(r"^(\d+)\s+", row["name"])
                orig = m.group(1) if m else "?"
                suffix = " [→15]" if orig != "15" else ""
                result.append({
                    "name": (row["name"][:54] + suffix)[:60],
                    "price": p15,
                })
            break

    print(f"    итого: {len(result)} позиций")
    for ftype, label in FLOWER_TYPES:
        if seen[ftype] > 0:
            print(f"      {label}: {seen[ftype]} шт.")
    return result
def scrape_bbflowers():
    print("\n[2] bbflowers.ru")
    links = []
    for cat, limit in BB_CATS.items():
        cat_name = cat.strip("/").split("/")[-1]
        print(f"    /{cat_name}/...", end=" ", flush=True)
        chunk = bbflowers_category_links(cat, limit)
        print(f"{len(chunk)} шт.")
        links.extend(chunk)

    print(f"    всего ссылок: {len(links)}, идём за ценами...")
    result = []
    for i, (name, href) in enumerate(links, 1):
        print(f"    [{i:2d}/{len(links)}] {name[:45]}...", end=" ")
        per_piece = bbflowers_price(href)
        if per_piece:
            price_15 = round(per_piece * 15)
            print(f"{per_piece} р × 15 = {price_15}")
            result.append({"name": name, "price": price_15})
        else:
            print("цены нет")

    result = list({(r["name"], r["price"]): r for r in result}.values())
    print(f"    итого: {len(result)}")
    return result


# ─── cvetochnay-baza (ОптЦвет) ───────────────────────────────────────────────
# Простой каталог, всё в HTML. Карточка — div.product_list_item,
# цена лежит в тексте в виде "Цена: 265 руб."

def scrape_optcvet():
    url = "https://cvetochnay-baza.ru/catalog.html"
    print(f"\n[3] cvetochnay-baza.ru")
    soup = fetch(url)
    if not soup:
        return []

    cards = soup.select("div.product_list_item")
    print(f"    карточек: {len(cards)}")
    result = []

    for card in cards:
        name_el = card.select_one("div.product_list_name a") or card.select_one("a")
        name = name_el.get_text(strip=True) if name_el else ""
        if not name:
            continue

        if any(skip in name.lower() for skip in SKIP_OPTCVET):
            continue

        card_text = card.get_text(" ", strip=True)
        m = re.search(r"[Цц]ена\s*:?\s*(?:от\s*)?(\d[\d\s]*)\s*руб", card_text)
        if not m:
            continue

        per_piece = int(re.sub(r"\s", "", m.group(1)))
        if per_piece > MAX_PER_PIECE or per_piece < 50:
            continue

        price_15 = per_piece * 15
        result.append({"name": name[:60], "price": price_15})
        print(f"    {name[:40]:40s}  {per_piece} р × 15 = {price_15}")

    result = list({(r["name"], r["price"]): r for r in result}.values())
    print(f"    итого: {len(result)}")
    return result


# ─── графики ─────────────────────────────────────────────────────────────────

def shop_chart(rows, title, color, fname):
    df = pd.DataFrame(rows).sort_values("price").reset_index(drop=True)
    n = len(df)
    mean_v = df["price"].mean()
    med_v  = df["price"].median()
    min_v  = df["price"].min()
    max_v  = df["price"].max()

    fig, (left, right) = plt.subplots(
        1, 2, figsize=(18, max(7, n * 0.42)),
        gridspec_kw={"width_ratios": [3, 1]},
    )
    fig.suptitle(title, fontsize=14, fontweight="bold", y=1.01)

    bars = left.barh(df["name"], df["price"], color=color, edgecolor="white", height=0.72)
    left.set_xlabel("Цена, руб.", fontsize=11)
    left.set_title("Название и цена", fontsize=12, fontweight="bold")
    left.xaxis.set_major_formatter(mticker.FuncFormatter(rub))
    left.grid(axis="x", alpha=0.25)
    left.set_axisbelow(True)
    left.tick_params(axis="y", labelsize=8.5)

    gap = max_v * 0.008
    for bar, val in zip(bars, df["price"]):
        left.text(val + gap, bar.get_y() + bar.get_height() / 2,
                  f"{val:,}\u202f₽".replace(",", "\u202f"),
                  va="center", fontsize=8)

    left.axvline(mean_v, color="#E76F51", lw=1.6, ls="--",
                 label=f"Среднее\u2002{mean_v:,.0f}\u202f₽".replace(",", "\u202f"))
    left.axvline(med_v,  color="#264653", lw=1.6, ls=":",
                 label=f"Медиана\u2002{med_v:,.0f}\u202f₽".replace(",", "\u202f"))
    left.legend(fontsize=9, loc="lower right")

    stat_bars = right.bar(["Среднее", "Медиана"], [mean_v, med_v],
                          color=["#E76F51", "#264653"], edgecolor="white", width=0.45)
    right.set_ylabel("Цена, руб.", fontsize=11)
    right.set_title("Среднее и медиана", fontsize=12, fontweight="bold")
    right.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    right.grid(axis="y", alpha=0.25)
    right.set_axisbelow(True)

    top = max_v * 0.025
    for bar, val in zip(stat_bars, [mean_v, med_v]):
        right.text(bar.get_x() + bar.get_width() / 2, val + top,
                   f"{val:,.0f}\u202f₽".replace(",", "\u202f"),
                   ha="center", fontsize=12, fontweight="bold")

    note = (f"Позиций:  {n}\n"
            f"Мин:  {min_v:,}\u202f₽\n".replace(",", "\u202f") +
            f"Макс: {max_v:,}\u202f₽".replace(",", "\u202f"))
    right.text(0.5, 0.06, note, transform=right.transAxes,
               ha="center", va="bottom", fontsize=9,
               bbox=dict(boxstyle="round,pad=0.5", facecolor="#f0f9f4", edgecolor=color))

    plt.tight_layout()
    plt.savefig(fname, dpi=150, bbox_inches="tight")
    plt.close()
    print(f"  → {fname}")


def comparison_chart(shops):
    # shops — список {"label", "rows", "color"}
    shops = [s for s in shops if s["rows"]]
    if not shops:
        return

    labels = [s["label"] for s in shops]
    colors = [s["color"] for s in shops]
    data   = [pd.Series([r["price"] for r in s["rows"]]) for s in shops]

    means   = [d.mean()   for d in data]
    medians = [d.median() for d in data]
    mins    = [d.min()    for d in data]
    maxs    = [d.max()    for d in data]
    stds    = [d.std()    for d in data]
    counts  = [len(d)     for d in data]

    # Короткое имя для оси — до первого тире или скобки
    short = [l.split("—")[0].strip().split("(")[0].strip() for l in labels]

    fig = plt.figure(figsize=(18, 14))
    fig.suptitle("Сравнение цен на букеты из 15 цветов — все три магазина",
                 fontsize=15, fontweight="bold", y=1.01)
    gs = fig.add_gridspec(2, 2, hspace=0.45, wspace=0.35)

    # средняя цена
    ax = fig.add_subplot(gs[0, 0])
    bars = ax.bar(short, means, color=colors, edgecolor="white", width=0.5)
    ax.set_title("Средняя цена букета", fontsize=12, fontweight="bold")
    ax.set_ylabel("Руб.")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    ax.grid(axis="y", alpha=0.25)
    ax.set_axisbelow(True)
    for bar, val in zip(bars, means):
        ax.text(bar.get_x() + bar.get_width() / 2, val + max(means) * 0.02,
                f"{val:,.0f}\u202f₽".replace(",", "\u202f"),
                ha="center", fontsize=11, fontweight="bold")

    # медиана
    ax = fig.add_subplot(gs[0, 1])
    bars = ax.bar(short, medians, color=colors, edgecolor="white", width=0.5)
    ax.set_title("Медианная цена букета", fontsize=12, fontweight="bold")
    ax.set_ylabel("Руб.")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    ax.grid(axis="y", alpha=0.25)
    ax.set_axisbelow(True)
    for bar, val in zip(bars, medians):
        ax.text(bar.get_x() + bar.get_width() / 2, val + max(medians) * 0.02,
                f"{val:,.0f}\u202f₽".replace(",", "\u202f"),
                ha="center", fontsize=11, fontweight="bold")

    # бокс-плот
    ax = fig.add_subplot(gs[1, 0])
    bp = ax.boxplot([d.tolist() for d in data], labels=short,
                    patch_artist=True, widths=0.45,
                    medianprops=dict(color="white", linewidth=2))
    for patch, c in zip(bp["boxes"], colors):
        patch.set_facecolor(c)
        patch.set_alpha(0.82)
    for elem in ["whiskers", "caps", "fliers"]:
        for line in bp[elem]:
            line.set_color("#555")
    ax.set_title("Разброс цен", fontsize=12, fontweight="bold")
    ax.set_ylabel("Руб.")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    ax.grid(axis="y", alpha=0.25)
    ax.set_axisbelow(True)

    # таблица метрик
    ax = fig.add_subplot(gs[1, 1])
    ax.axis("off")
    ax.set_title("Ключевые метрики", fontsize=12, fontweight="bold")

    headers = ["Магазин", "Поз.", "Мин ₽", "Среднее ₽", "Медиана ₽", "Макс ₽", "Разброс ₽"]
    rows = []
    for i in range(len(shops)):
        rows.append([
            short[i],
            str(counts[i]),
            f"{int(mins[i]):,}".replace(",", "\u202f"),
            f"{int(means[i]):,}".replace(",", "\u202f"),
            f"{int(medians[i]):,}".replace(",", "\u202f"),
            f"{int(maxs[i]):,}".replace(",", "\u202f"),
            f"{int(stds[i]):,}".replace(",", "\u202f"),
        ])

    tbl = ax.table(cellText=rows, colLabels=headers,
                   cellLoc="center", loc="upper center",
                   bbox=[0, 0.38, 1, 0.58])
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(8.5)
    for j in range(len(headers)):
        tbl[0, j].set_facecolor("#2D6A4F")
        tbl[0, j].set_text_props(color="white", fontweight="bold")
    for i in range(1, len(rows) + 1):
        bg = "#f0f9f4" if i % 2 == 0 else "white"
        for j in range(len(headers)):
            tbl[i, j].set_facecolor(bg)

    cheapest  = short[means.index(min(means))]
    mid_shop  = short[medians.index(min(medians))]
    widest    = short[stds.index(max(stds))]

    notes = [
        f"• Самая низкая средняя цена: {cheapest}",
        f"• Самая низкая медиана: {mid_shop}",
        f"• Наибольший разброс: {widest}",
        f"  (широкий разброс = разные ценовые сегменты)",
        "",
        "Вывод по закупке:",
        f"• Бюджетный букет — смотреть на {mid_shop}",
        f"• Разброс цен показывает вашу конкурентную нишу",
    ]
    y = 0.33
    for line in notes:
        bold  = "bold"   if line.startswith("Вывод") else "normal"
        color = "#1B4332" if line.startswith("Вывод") else "#333"
        ax.text(0.02, y, line, transform=ax.transAxes,
                fontsize=8.5, va="top", color=color, fontweight=bold)
        y -= 0.075

    plt.savefig("04_comparison.png", dpi=150, bbox_inches="tight")
    plt.close()
    print("  → 04_comparison.png")


# ─── main ─────────────────────────────────────────────────────────────────────

def main():
    print("Собираем данные по букетам из 15 цветов...\n")

    megacvet  = scrape_megacvet()
    bbflowers = scrape_bbflowers()
    optcvet   = scrape_optcvet()

    if not any([megacvet, bbflowers, optcvet]):
        print("\nНи один сайт не ответил — проверь соединение.")
        sys.exit(1)

    all_data = (
        [{"source": "МегаЦвет24",   **r} for r in megacvet]  +
        [{"source": "BBFlowers ×15", **r} for r in bbflowers] +
        [{"source": "ОптЦвет ×15",  **r} for r in optcvet]
    )
    pd.DataFrame(all_data).to_csv("bouquets_data.csv", index=False, encoding="utf-8-sig")
    print(f"\nbouquets_data.csv — {len(all_data)} строк")

    print("\nСтроим графики...")
    if megacvet:
        shop_chart(megacvet,  "МегаЦвет24 — букеты из 15 цветов",
                   "#2D6A4F", "01_megacvet.png")
    if bbflowers:
        shop_chart(bbflowers, "BBFlowers — цветы поштучно × 15",
                   "#E76F51", "02_bbflowers.png")
    if optcvet:
        shop_chart(optcvet,   "ОптЦвет — цветы поштучно × 15",
                   "#74C69D", "03_optcvet.png")

    comparison_chart([
        {"label": "МегаЦвет24",   "rows": megacvet,  "color": "#2D6A4F"},
        {"label": "BBFlowers ×15", "rows": bbflowers, "color": "#E76F51"},
        {"label": "ОптЦвет ×15",  "rows": optcvet,   "color": "#74C69D"},
    ])

    print("\n" + "─" * 50)
    for label, rows in [("МегаЦвет24", megacvet),
                        ("BBFlowers ×15", bbflowers),
                        ("ОптЦвет ×15",  optcvet)]:
        if not rows:
            continue
        p = pd.Series([r["price"] for r in rows])
        q1, q3 = p.quantile(0.25), p.quantile(0.75)
        print(f"\n{label}  ({len(p)} поз.)")
        print(f"  мин / макс   : {p.min():,} — {p.max():,} руб.")
        print(f"  среднее      : {p.mean():,.0f} руб.")
        print(f"  медиана      : {p.median():,.0f} руб.")
        print(f"  разброс (σ)  : {p.std():,.0f} руб.")
        print(f"  IQR 25–75%   : {q1:,.0f} — {q3:,.0f} руб.")
    print("─" * 50)


if __name__ == "__main__":
    main()
# Out:
# Собираем данные по букетам из 15 цветов...
#
#
# [1] megacvet24.ru — все 18 страниц, по 3 позиции каждого типа
#     стр. 1: 40 карточек
#     всего до фильтрации: 40
#     итого: 12 позиций
#       Роза: 3 шт.
#       Гвоздика: 3 шт.
#       Пион: 2 шт.
#       Лилия: 1 шт.
#       Альстромерия: 2 шт.
#       Сирень: 1 шт.
#
# [2] bbflowers.ru
#     /roza/... 4 шт.
#     /hrizantema/... 3 шт.
#     /tyulpan/... 0 шт.
#     /pion/... 2 шт.
#     /liliya/... 1 шт.
#     /gerbera/... 2 шт.
#     /alstromeriya/... 1 шт.
#     /eustoma/... 2 шт.
#     всего ссылок: 15, идём за ценами...
#     [ 1/15] Роза Gr Country Secret одноголовая 50 см... 100.0 р × 15 = 1500
#     [ 2/15] Роза Gr Wham одноголовая 40 см... 80.0 р × 15 = 1200
#     [ 3/15] Роза Tr Jullietta кустовая пионовидная 70 см... 250.0 р × 15 = 3750
#     [ 4/15] Роза Tr Pushkin кустовая 60 см... 180.0 р × 15 = 2700
#     [ 5/15] Сантини Peptalk 55 см... 90.0 р × 15 = 1350
#     [ 6/15] Хризантема G Momoko одноголовая 70 см... 200.0 р × 15 = 3000
#     [ 7/15] Хризантема T Kennedy кустовая 70 см... 160.0 р × 15 = 2400
#     [ 8/15] Пион Belgravia 60 см... 300.0 р × 15 = 4500
#     [ 9/15] Пион L Mme Cl Tain 50 см... 400.0 р × 15 = 6000
#     [10/15] Лилия Or Du Anouska 90 см 5+ махровая... 700.0 р × 15 = 10500
#     [11/15] Гербера аква mix... 150.0 р × 15 = 2250
#     [12/15] Гермини Snoopy 50 см... 100.0 р × 15 = 1500
#     [13/15] Альстромерия Mix 80 см (Tessa)... 150.0 р × 15 = 2250
#     [14/15] Эустома G Alissa Champagne махровая 70 см... 300.0 р × 15 = 4500
#     [15/15] Эустома G Alissa Pure White махровая 70 см... 280.0 р × 15 = 4200
#     итого: 15
#
# [3] cvetochnay-baza.ru
#     карточек: 83
#     Розы микс 1                               439 р × 15 = 6585
#     Розы микс 2                               439 р × 15 = 6585
#     Роза Мондиаль                             265 р × 15 = 3975
#     Роза Мохана                               265 р × 15 = 3975
#     Роза кустовая                             265 р × 15 = 3975
#     Роза Габарет                              265 р × 15 = 3975
#     Роза Ангажемент                           265 р × 15 = 3975
#     Роза Новиа                                265 р × 15 = 3975
#     Белая роза Венделла                       265 р × 15 = 3975
#     Роза Карусель                             265 р × 15 = 3975
#     Роза Дип Пёрпл                            265 р × 15 = 3975
#     Роза Малибу                               265 р × 15 = 3975
#     Роза Амстердам                            265 р × 15 = 3975
#     Роза 3Д                                   265 р × 15 = 3975
#     Роза Хермоса                              265 р × 15 = 3975
#     Роза Меджик Таймс                         265 р × 15 = 3975
#     Роза Свитнесс                             265 р × 15 = 3975
#     Роза Фридом                               265 р × 15 = 3975
#     Роза Хаймеджик                            265 р × 15 = 3975
#     Роза Топаз                                265 р × 15 = 3975
#     Роза Игуана                               265 р × 15 = 3975
#     Тюльпан желтый                            169 р × 15 = 2535
#     Гербера                                   229 р × 15 = 3435
#     Альстромерия                              219 р × 15 = 3285
#     Тюльпан белый                             169 р × 15 = 2535
#     Тюльпан микс                              169 р × 15 = 2535
#     Тюльпан розовый                           169 р × 15 = 2535
#     Хризантема одноголовая                    419 р × 15 = 6285
#     Хризантема кустовая                       155 р × 15 = 2325
#     Дендробиум                                189 р × 15 = 2835
#     Роза Эсперанса                            265 р × 15 = 3975
#     Роза синяя                                265 р × 15 = 3975
#     Роза радужная 1                           439 р × 15 = 6585
#     Роза радужная 2                           439 р × 15 = 6585
#     Гвоздика кустовая                         119 р × 15 = 1785
#     Гвоздика одноголовая                      119 р × 15 = 1785
#     Ирис                                      149 р × 15 = 2235
#     Роза CerryBrandy                          265 р × 15 = 3975
#     Роза Эксплорер                            293 р × 15 = 4395
#     Роза Хермоза                              265 р × 15 = 3975
#     Роза Пинк Флойд                           265 р × 15 = 3975
#     Роза Пинк Мондиаль                        265 р × 15 = 3975
#     Роза Лимонад                              265 р × 15 = 3975
#     Тюльпан Пионовидный                       189 р × 15 = 2835
#     Гвоздика микс                             119 р × 15 = 1785
#     Ирис белый                                149 р × 15 = 2235
#     Хризантема одноголовая жёлтая             419 р × 15 = 6285
#     Хризантема одноголовая зембла белая       419 р × 15 = 6285
#     Роза Тара                                 265 р × 15 = 3975
#     итого: 49
#
# bouquets_data.csv — 76 строк
#
# Строим графики...
#   → 01_megacvet.png
#   → 02_bbflowers.png
#   → 03_optcvet.png
# /tmp/ipykernel_11778/2869770555.py:380: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot([d.tolist() for d in data], labels=short,
#   → 04_comparison.png
#
# ──────────────────────────────────────────────────
#
# МегаЦвет24  (12 поз.)
#   мин / макс   : 2,099 — 6,199 руб.
#   среднее      : 3,141 руб.
#   медиана      : 2,449 руб.
#   разброс (σ)  : 1,385 руб.
#   IQR 25–75%   : 2,274 — 3,799 руб.
#
# BBFlowers ×15  (15 поз.)
#   мин / макс   : 1,200 — 10,500 руб.
#   среднее      : 3,440 руб.
#   медиана      : 2,700 руб.
#   разброс (σ)  : 2,404 руб.
#   IQR 25–75%   : 1,875 — 4,350 руб.
#
# ОптЦвет ×15  (49 поз.)
#   мин / макс   : 1,785 — 6,585 руб.
#   среднее      : 3,910 руб.
#   медиана      : 3,975 руб.
#   разброс (σ)  : 1,275 руб.
#   IQR 25–75%   : 3,285 — 3,975 руб.
# ──────────────────────────────────────────────────

# %%
# Сравниваем цены на букеты из 15 цветов по трём источникам:
#
#   1. megacvet24.ru/15-tsvetov  — готовые букеты, цены как есть
#   2. bbflowers.ru              — оптовый прайс поштучно, берём × 15
#                                  выборка по категориям чтобы захватить
#                                  разные ценовые сегменты
#   3. cvetochnay-baza.ru        — розничный каталог поштучно, тоже × 15
#                                  корзины и орхидеи убираем — они ломают картину
#
# Запуск: python parse_bouquets.py
# Нужно: requests, beautifulsoup4, pandas, matplotlib

import re
import sys
import time
import random

import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.rcParams["font.family"] = "DejaVu Sans"
plt.rcParams["axes.unicode_minus"] = False

UA = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "ru-RU,ru;q=0.9",
    "Accept": "text/html,application/xhtml+xml,*/*;q=0.8",
}

# bbflowers разбит по категориям — берём из каждой несколько позиций
# равномерно, чтобы не получился алфавитный срез одной цены
BB_CATS = {
    "/catalog/roza/":         4,
    "/catalog/hrizantema/":   3,
    "/catalog/tyulpan/":      3,
    "/catalog/pion/":         2,
    "/catalog/liliya/":       2,
    "/catalog/gerbera/":      2,
    "/catalog/alstromeriya/": 2,
    "/catalog/eustoma/":      2,
}

# на оптцвет корзины стоят по 4-12 тысяч — это не цветы поштучно,
# убираем их вместе с орхидеями и цимбидиумом (слишком редкие/дорогие)
SKIP_OPTCVET = {"корзина", "цимбидиум", "орхидея", "орхид"}
MAX_PER_PIECE = 600  # выше этого — что-то пошло не так


def fetch(url, pause=True):
    if pause:
        time.sleep(random.uniform(1.0, 2.0))
    s = requests.Session()
    s.headers.update(UA)
    r = s.get(url, timeout=15)
    if r.status_code != 200:
        print(f"    ! {r.status_code} на {url}")
        return None
    return BeautifulSoup(r.text, "html.parser")


def rub(x, _=None):
    return f"{int(x):,}".replace(",", "\u202f")


# ─── megacvet24 ───────────────────────────────────────────────────────────────
# Берём монобукеты — в названии одно числительное и один вид цветка.
# Пример: "15 Красных Роз", "19 Пионов Микс", "9 Белых Лилий".
# Цену пересчитываем на 15: цена / количество * 15.
# По одной позиции из каждого раздела — так получаем разнообразие.

MEGACVET_SECTIONS = [
    "https://megacvet24.ru/rozy/",
    "https://megacvet24.ru/krasnye-rozy/",
    "https://megacvet24.ru/belye-rozy/",
    "https://megacvet24.ru/zheltye-rozy/",
    "https://megacvet24.ru/piony/",
    "https://megacvet24.ru/gortenzii/",
    "https://megacvet24.ru/lilii/",
    "https://megacvet24.ru/hrizantemy/",
    "https://megacvet24.ru/alstromerii/",
    "https://megacvet24.ru/irisy/",
    "https://megacvet24.ru/gerbery/",
    "https://megacvet24.ru/eustomy/",
    "https://megacvet24.ru/gvozdiki/",
    "https://megacvet24.ru/podsolnuhi/",
    "https://megacvet24.ru/romashki/",
    "https://megacvet24.ru/orhidei/",
    "https://megacvet24.ru/orhideya-dendrobium/",
    "https://megacvet24.ru/tulpany/",
    "https://megacvet24.ru/gipsofila/",
    "https://megacvet24.ru/verba/",
]


def is_mono(name):
    # Монобукет: начинается с числа, в названии нет союза "и"
    # и нет слов намекающих на микс нескольких видов
    if not re.match(r"^\d+\s+", name):
        return False
    name_low = name.lower()
    if " и " in name_low:
        return False
    # "микс" из разных видов тоже пропускаем, но "микс" одного — ок
    # ("15 Роз Микс" — один вид, "15 Роз и Пионов Микс" — уже два,
    # но второй отсеется по " и ")
    return True


def price_per_15(name, price):
    m = re.match(r"^(\d+)\s+", name)
    if not m:
        return None
    count = int(m.group(1))
    if count == 0:
        return None
    return round(price / count * 15)


def cheapest_mono_from_section(url):
    # Перебираем все страницы раздела, собираем все монобукеты,
    # возвращаем самый дешёвый после пересчёта на 15
    candidates = []

    for page in range(1, 6):
        paged = url if page == 1 else f"{url}?page={page}"
        soup = fetch(paged)
        if not soup:
            break

        cards = soup.select("div.list-product")
        if not cards:
            break

        for card in cards:
            name_el = card.select_one("a.list-product__name span") \
                   or card.select_one("a.list-product__name")
            name = name_el.get_text(strip=True) if name_el else ""
            if not is_mono(name):
                continue

            price = None
            meta = card.select_one('meta[itemprop="price"]')
            if meta and meta.get("content"):
                try:
                    price = int(float(meta["content"]))
                except ValueError:
                    pass

            if not price:
                span = card.select_one("span.list-product__price")
                if span:
                    for junk in span.select("span"):
                        junk.decompose()
                    digits = re.sub(r"[^\d]", "", span.get_text())
                    if digits:
                        price = int(digits)

            if not price or price < 200 or price > 500_000:
                continue

            p15 = price_per_15(name, price)
            if not p15:
                continue

            m = re.match(r"^(\d+)\s+", name)
            count = m.group(1) if m else "?"
            label = name[:50] + (" [×15]" if count != "15" else "")
            candidates.append({"name": label[:60], "price": p15})

        if not soup.select_one("a[rel='next'], a[class*='next'], .pagination__next"):
            break

    if not candidates:
        return None
    return min(candidates, key=lambda r: r["price"])


def scrape_megacvet():
    print("\n[1] megacvet24.ru — монобукеты, цена пересчитана на 15 цветков")
    result = []
    seen_names = set()

    for url in MEGACVET_SECTIONS:
        section = url.rstrip("/").split("/")[-1]
        print(f"    /{section}/...", end=" ", flush=True)
        row = cheapest_mono_from_section(url)
        if row and row["name"] not in seen_names:
            seen_names.add(row["name"])
            result.append(row)
            print(f"{row['name'][:40]} — {row['price']} руб.")
        else:
            print("не найдено или дубль")

    print(f"    итого: {len(result)} позиций")
    return result


def scrape_bbflowers():
    print("\n[2] bbflowers.ru")
    links = []
    for cat, limit in BB_CATS.items():
        cat_name = cat.strip("/").split("/")[-1]
        print(f"    /{cat_name}/...", end=" ", flush=True)
        chunk = bbflowers_category_links(cat, limit)
        print(f"{len(chunk)} шт.")
        links.extend(chunk)

    print(f"    всего ссылок: {len(links)}, идём за ценами...")
    result = []
    for i, (name, href) in enumerate(links, 1):
        print(f"    [{i:2d}/{len(links)}] {name[:45]}...", end=" ")
        per_piece = bbflowers_price(href)
        if per_piece:
            price_15 = round(per_piece * 15)
            print(f"{per_piece} р × 15 = {price_15}")
            result.append({"name": name, "price": price_15})
        else:
            print("цены нет")

    result = list({(r["name"], r["price"]): r for r in result}.values())
    print(f"    итого: {len(result)}")
    return result


# ─── cvetochnay-baza (ОптЦвет) ───────────────────────────────────────────────
# Простой каталог, всё в HTML. Карточка — div.product_list_item,
# цена лежит в тексте в виде "Цена: 265 руб."

# Типы цветов для оптцвет — берём самый дешёвый вариант каждого типа.
# Ключ — подстрока в названии, значение — человекочитаемый ярлык.
OPTCVET_TYPES = [
    ("роза",        "Роза"),
    ("тюльпан",     "Тюльпан"),
    ("гербер",      "Гербера"),
    ("альстромери", "Альстромерия"),
    ("хризантем",   "Хризантема"),
    ("дендробиум",  "Дендробиум"),
    ("гвоздик",     "Гвоздика"),
    ("ирис",        "Ирис"),
]


def scrape_optcvet():
    url = "https://cvetochnay-baza.ru/catalog.html"
    print(f"\n[3] cvetochnay-baza.ru — по одному дешёвому варианту каждого типа")
    soup = fetch(url)
    if not soup:
        return []

    cards = soup.select("div.product_list_item")
    print(f"    карточек на странице: {len(cards)}")

    # Сначала собираем все позиции с ценами
    all_items = []
    for card in cards:
        name_el = card.select_one("div.product_list_name a") or card.select_one("a")
        name = name_el.get_text(strip=True) if name_el else ""
        if not name:
            continue
        if any(skip in name.lower() for skip in SKIP_OPTCVET):
            continue

        card_text = card.get_text(" ", strip=True)
        m = re.search(r"[Цц]ена\s*:?\s*(?:от\s*)?(\d[\d\s]*)\s*руб", card_text)
        if not m:
            continue

        per_piece = int(re.sub(r"\s", "", m.group(1)))
        if per_piece > MAX_PER_PIECE or per_piece < 50:
            continue

        all_items.append({"name": name, "per_piece": per_piece})

    # Из каждого типа берём самый дешёвый
    result = []
    for ftype, label in OPTCVET_TYPES:
        candidates = [i for i in all_items if ftype in i["name"].lower()]
        if not candidates:
            print(f"    {label}: не найдено")
            continue
        cheapest = min(candidates, key=lambda i: i["per_piece"])
        price_15 = cheapest["per_piece"] * 15
        result.append({"name": cheapest["name"][:60], "price": price_15})
        print(f"    {label}: {cheapest['name'][:35]} — {cheapest['per_piece']} р × 15 = {price_15}")

    print(f"    итого: {len(result)}")
    return result


# ─── графики ─────────────────────────────────────────────────────────────────

def shop_chart(rows, title, color, fname):
    df = pd.DataFrame(rows).sort_values("price").reset_index(drop=True)
    n = len(df)
    mean_v = df["price"].mean()
    med_v  = df["price"].median()
    min_v  = df["price"].min()
    max_v  = df["price"].max()

    fig, (left, right) = plt.subplots(
        1, 2, figsize=(18, max(7, n * 0.42)),
        gridspec_kw={"width_ratios": [3, 1]},
    )
    fig.suptitle(title, fontsize=14, fontweight="bold", y=1.01)

    bars = left.barh(df["name"], df["price"], color=color, edgecolor="white", height=0.72)
    left.set_xlabel("Цена, руб.", fontsize=11)
    left.set_title("Название и цена", fontsize=12, fontweight="bold")
    left.xaxis.set_major_formatter(mticker.FuncFormatter(rub))
    left.grid(axis="x", alpha=0.25)
    left.set_axisbelow(True)
    left.tick_params(axis="y", labelsize=8.5)

    gap = max_v * 0.008
    for bar, val in zip(bars, df["price"]):
        left.text(val + gap, bar.get_y() + bar.get_height() / 2,
                  f"{val:,}\u202f₽".replace(",", "\u202f"),
                  va="center", fontsize=8)

    left.axvline(mean_v, color="#E76F51", lw=1.6, ls="--",
                 label=f"Среднее\u2002{mean_v:,.0f}\u202f₽".replace(",", "\u202f"))
    left.axvline(med_v,  color="#264653", lw=1.6, ls=":",
                 label=f"Медиана\u2002{med_v:,.0f}\u202f₽".replace(",", "\u202f"))
    left.legend(fontsize=9, loc="lower right")

    stat_bars = right.bar(["Среднее", "Медиана"], [mean_v, med_v],
                          color=["#E76F51", "#264653"], edgecolor="white", width=0.45)
    right.set_ylabel("Цена, руб.", fontsize=11)
    right.set_title("Среднее и медиана", fontsize=12, fontweight="bold")
    right.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    right.grid(axis="y", alpha=0.25)
    right.set_axisbelow(True)

    top = max_v * 0.025
    for bar, val in zip(stat_bars, [mean_v, med_v]):
        right.text(bar.get_x() + bar.get_width() / 2, val + top,
                   f"{val:,.0f}\u202f₽".replace(",", "\u202f"),
                   ha="center", fontsize=12, fontweight="bold")

    note = (f"Позиций:  {n}\n"
            f"Мин:  {min_v:,}\u202f₽\n".replace(",", "\u202f") +
            f"Макс: {max_v:,}\u202f₽".replace(",", "\u202f"))
    right.text(0.5, 0.06, note, transform=right.transAxes,
               ha="center", va="bottom", fontsize=9,
               bbox=dict(boxstyle="round,pad=0.5", facecolor="#f0f9f4", edgecolor=color))

    plt.tight_layout()
    plt.savefig(fname, dpi=150, bbox_inches="tight")
    plt.close()
    print(f"  → {fname}")


def comparison_chart(shops):
    # shops — список {"label", "rows", "color"}
    shops = [s for s in shops if s["rows"]]
    if not shops:
        return

    labels = [s["label"] for s in shops]
    colors = [s["color"] for s in shops]
    data   = [pd.Series([r["price"] for r in s["rows"]]) for s in shops]

    means   = [d.mean()   for d in data]
    medians = [d.median() for d in data]
    mins    = [d.min()    for d in data]
    maxs    = [d.max()    for d in data]
    stds    = [d.std()    for d in data]
    counts  = [len(d)     for d in data]

    # Короткое имя для оси — до первого тире или скобки
    short = [l.split("—")[0].strip().split("(")[0].strip() for l in labels]

    fig = plt.figure(figsize=(18, 14))
    fig.suptitle("Сравнение цен на букеты из 15 цветов — все три магазина",
                 fontsize=15, fontweight="bold", y=1.01)
    gs = fig.add_gridspec(2, 2, hspace=0.45, wspace=0.35)

    # средняя цена
    ax = fig.add_subplot(gs[0, 0])
    bars = ax.bar(short, means, color=colors, edgecolor="white", width=0.5)
    ax.set_title("Средняя цена букета", fontsize=12, fontweight="bold")
    ax.set_ylabel("Руб.")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    ax.grid(axis="y", alpha=0.25)
    ax.set_axisbelow(True)
    for bar, val in zip(bars, means):
        ax.text(bar.get_x() + bar.get_width() / 2, val + max(means) * 0.02,
                f"{val:,.0f}\u202f₽".replace(",", "\u202f"),
                ha="center", fontsize=11, fontweight="bold")

    # медиана
    ax = fig.add_subplot(gs[0, 1])
    bars = ax.bar(short, medians, color=colors, edgecolor="white", width=0.5)
    ax.set_title("Медианная цена букета", fontsize=12, fontweight="bold")
    ax.set_ylabel("Руб.")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    ax.grid(axis="y", alpha=0.25)
    ax.set_axisbelow(True)
    for bar, val in zip(bars, medians):
        ax.text(bar.get_x() + bar.get_width() / 2, val + max(medians) * 0.02,
                f"{val:,.0f}\u202f₽".replace(",", "\u202f"),
                ha="center", fontsize=11, fontweight="bold")

    # бокс-плот
    ax = fig.add_subplot(gs[1, 0])
    bp = ax.boxplot([d.tolist() for d in data], labels=short,
                    patch_artist=True, widths=0.45,
                    medianprops=dict(color="white", linewidth=2))
    for patch, c in zip(bp["boxes"], colors):
        patch.set_facecolor(c)
        patch.set_alpha(0.82)
    for elem in ["whiskers", "caps", "fliers"]:
        for line in bp[elem]:
            line.set_color("#555")
    ax.set_title("Разброс цен", fontsize=12, fontweight="bold")
    ax.set_ylabel("Руб.")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(rub))
    ax.grid(axis="y", alpha=0.25)
    ax.set_axisbelow(True)

    # таблица метрик
    ax = fig.add_subplot(gs[1, 1])
    ax.axis("off")
    ax.set_title("Ключевые метрики", fontsize=12, fontweight="bold")

    headers = ["Магазин", "Поз.", "Мин ₽", "Среднее ₽", "Медиана ₽", "Макс ₽", "Разброс ₽"]
    rows = []
    for i in range(len(shops)):
        rows.append([
            short[i],
            str(counts[i]),
            f"{int(mins[i]):,}".replace(",", "\u202f"),
            f"{int(means[i]):,}".replace(",", "\u202f"),
            f"{int(medians[i]):,}".replace(",", "\u202f"),
            f"{int(maxs[i]):,}".replace(",", "\u202f"),
            f"{int(stds[i]):,}".replace(",", "\u202f"),
        ])

    tbl = ax.table(cellText=rows, colLabels=headers,
                   cellLoc="center", loc="upper center",
                   bbox=[0, 0.38, 1, 0.58])
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(8.5)
    for j in range(len(headers)):
        tbl[0, j].set_facecolor("#2D6A4F")
        tbl[0, j].set_text_props(color="white", fontweight="bold")
    for i in range(1, len(rows) + 1):
        bg = "#f0f9f4" if i % 2 == 0 else "white"
        for j in range(len(headers)):
            tbl[i, j].set_facecolor(bg)

    cheapest  = short[means.index(min(means))]
    mid_shop  = short[medians.index(min(medians))]
    widest    = short[stds.index(max(stds))]

    notes = [
        f"• Самая низкая средняя цена: {cheapest}",
        f"• Самая низкая медиана: {mid_shop}",
        f"• Наибольший разброс: {widest}",
        f"  (широкий разброс = разные ценовые сегменты)",
        "",
        "Вывод по закупке:",
        f"• Бюджетный букет — смотреть на {mid_shop}",
        f"• Разброс цен показывает вашу конкурентную нишу",
    ]
    y = 0.33
    for line in notes:
        bold  = "bold"   if line.startswith("Вывод") else "normal"
        color = "#1B4332" if line.startswith("Вывод") else "#333"
        ax.text(0.02, y, line, transform=ax.transAxes,
                fontsize=8.5, va="top", color=color, fontweight=bold)
        y -= 0.075

    plt.savefig("04_comparison.png", dpi=150, bbox_inches="tight")
    plt.close()
    print("  → 04_comparison.png")


# ─── main ─────────────────────────────────────────────────────────────────────

def main():
    print("Собираем данные по букетам из 15 цветов...\n")

    megacvet  = scrape_megacvet()
    bbflowers = scrape_bbflowers()
    optcvet   = scrape_optcvet()

    if not any([megacvet, bbflowers, optcvet]):
        print("\nНи один сайт не ответил — проверь соединение.")
        sys.exit(1)

    all_data = (
        [{"source": "МегаЦвет24",   **r} for r in megacvet]  +
        [{"source": "BBFlowers ×15", **r} for r in bbflowers] +
        [{"source": "ОптЦвет ×15",  **r} for r in optcvet]
    )
    pd.DataFrame(all_data).to_csv("bouquets_data.csv", index=False, encoding="utf-8-sig")
    print(f"\nbouquets_data.csv — {len(all_data)} строк")

    print("\nСтроим графики...")
    if megacvet:
        shop_chart(megacvet,  "МегаЦвет24 — букеты из 15 цветов",
                   "#2D6A4F", "01_megacvet.png")
    if bbflowers:
        shop_chart(bbflowers, "BBFlowers — цветы поштучно × 15",
                   "#E76F51", "02_bbflowers.png")
    if optcvet:
        shop_chart(optcvet,   "ОптЦвет — цветы поштучно × 15",
                   "#74C69D", "03_optcvet.png")

    comparison_chart([
        {"label": "МегаЦвет24",   "rows": megacvet,  "color": "#2D6A4F"},
        {"label": "BBFlowers ×15", "rows": bbflowers, "color": "#E76F51"},
        {"label": "ОптЦвет ×15",  "rows": optcvet,   "color": "#74C69D"},
    ])

    print("\n" + "─" * 50)
    for label, rows in [("МегаЦвет24", megacvet),
                        ("BBFlowers ×15", bbflowers),
                        ("ОптЦвет ×15",  optcvet)]:
        if not rows:
            continue
        p = pd.Series([r["price"] for r in rows])
        q1, q3 = p.quantile(0.25), p.quantile(0.75)
        print(f"\n{label}  ({len(p)} поз.)")
        print(f"  мин / макс   : {p.min():,} — {p.max():,} руб.")
        print(f"  среднее      : {p.mean():,.0f} руб.")
        print(f"  медиана      : {p.median():,.0f} руб.")
        print(f"  разброс (σ)  : {p.std():,.0f} руб.")
        print(f"  IQR 25–75%   : {q1:,.0f} — {q3:,.0f} руб.")
    print("─" * 50)


if __name__ == "__main__":
    main()
# Out:
# Собираем данные по букетам из 15 цветов...
#
#
# [1] megacvet24.ru — монобукеты, цена пересчитана на 15 цветков
#     /rozy/... 101 Малиновая Роза Шангри Ла (40 см) [×1 — 1440 руб.
#     /krasnye-rozy/... 101 Красная Роза Ред Наоми (40 см) [×15] — 1604 руб.
#     /belye-rozy/... 25 Бело-Розовых Роз Джумилия (40 см) [×1 — 1799 руб.
#     /zheltye-rozy/... 151 Желтая Роза (40 см.) [×15] — 1341 руб.
#     /piony/... 15 Красных Пионов Ред Шарм — 4299 руб.
#     /gortenzii/... 15 Белых Гортензий — 10499 руб.
#     /lilii/... 51 Разноцветная Лилия Микс [×15] — 4559 руб.
#     /hrizantemy/... 51 Кустовая Хризантема Микс [×15] — 5382 руб.
#     /alstromerii/... 101 Разноцветная Альстромерия Микс в кор — 2302 руб.
#     /irisy/... 19 Синих Ирисов [×15] — 2841 руб.
#     /gerbery/... 101 Гербера Микс [×15] — 2599 руб.
#     /eustomy/... 15 Розовых Эустом — 9699 руб.
#     /gvozdiki/... 25 Красных Гвоздик под Георгиевскую лент — 1859 руб.
#     /podsolnuhi/... 151 Подсолнух [×15] — 8116 руб.
#     /romashki/... 101 Кустовая Ромашка [×15] — 2747 руб.
#     /orhidei/... 35 Цветков Орхидеи Космос Синей [×15] — 1285 руб.
#     /orhideya-dendrobium/... не найдено или дубль
#     /tulpany/...     ! 404 на https://megacvet24.ru/tulpany/
# не найдено или дубль
#     /gipsofila/... 51 Радужная Гипсофила [×15] — 2029 руб.
#     /verba/... не найдено или дубль
#     итого: 17 позиций
#
# [2] bbflowers.ru
#     /roza/... 4 шт.
#     /hrizantema/... 3 шт.
#     /tyulpan/... 0 шт.
#     /pion/... 2 шт.
#     /liliya/... 1 шт.
#     /gerbera/... 2 шт.
#     /alstromeriya/... 1 шт.
#     /eustoma/... 2 шт.
#     всего ссылок: 15, идём за ценами...
#     [ 1/15] Роза Gr Country Secret одноголовая 50 см... 100.0 р × 15 = 1500
#     [ 2/15] Роза Gr Wham одноголовая 40 см... 80.0 р × 15 = 1200
#     [ 3/15] Роза Tr Jullietta кустовая пионовидная 70 см... 250.0 р × 15 = 3750
#     [ 4/15] Роза Tr Pushkin кустовая 60 см... 180.0 р × 15 = 2700
#     [ 5/15] Сантини Peptalk 55 см... 90.0 р × 15 = 1350
#     [ 6/15] Хризантема G Momoko одноголовая 70 см... 200.0 р × 15 = 3000
#     [ 7/15] Хризантема T Kennedy кустовая 70 см... 160.0 р × 15 = 2400
#     [ 8/15] Пион Belgravia 60 см... 300.0 р × 15 = 4500
#     [ 9/15] Пион L Mme Cl Tain 50 см... 400.0 р × 15 = 6000
#     [10/15] Лилия Or Du Anouska 90 см 5+ махровая... 700.0 р × 15 = 10500
#     [11/15] Гербера аква mix... 150.0 р × 15 = 2250
#     [12/15] Гермини Snoopy 50 см... 100.0 р × 15 = 1500
#     [13/15] Альстромерия Mix 80 см (Tessa)... 150.0 р × 15 = 2250
#     [14/15] Эустома G Alissa Champagne махровая 70 см... 300.0 р × 15 = 4500
#     [15/15] Эустома G Alissa Pure White махровая 70 см... 280.0 р × 15 = 4200
#     итого: 15
#
# [3] cvetochnay-baza.ru — по одному дешёвому варианту каждого типа
#     карточек на странице: 83
#     Роза: Роза Мондиаль — 265 р × 15 = 3975
#     Тюльпан: Тюльпан желтый — 169 р × 15 = 2535
#     Гербера: Гербера — 229 р × 15 = 3435
#     Альстромерия: Альстромерия — 219 р × 15 = 3285
#     Хризантема: Хризантема кустовая — 155 р × 15 = 2325
#     Дендробиум: Дендробиум — 189 р × 15 = 2835
#     Гвоздика: Гвоздика кустовая — 119 р × 15 = 1785
#     Ирис: Ирис — 149 р × 15 = 2235
#     итого: 8
#
# bouquets_data.csv — 40 строк
#
# Строим графики...
#   → 01_megacvet.png
#   → 02_bbflowers.png
#   → 03_optcvet.png
# /tmp/ipykernel_11778/4028207861.py:413: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot([d.tolist() for d in data], labels=short,
#   → 04_comparison.png
#
# ──────────────────────────────────────────────────
#
# МегаЦвет24  (17 поз.)
#   мин / макс   : 1,285 — 10,499 руб.
#   среднее      : 3,788 руб.
#   медиана      : 2,599 руб.
#   разброс (σ)  : 2,969 руб.
#   IQR 25–75%   : 1,799 — 4,559 руб.
#
# BBFlowers ×15  (15 поз.)
#   мин / макс   : 1,200 — 10,500 руб.
#   среднее      : 3,440 руб.
#   медиана      : 2,700 руб.
#   разброс (σ)  : 2,404 руб.
#   IQR 25–75%   : 1,875 — 4,350 руб.
#
# ОптЦвет ×15  (8 поз.)
#   мин / макс   : 1,785 — 3,975 руб.
#   среднее      : 2,801 руб.
#   медиана      : 2,685 руб.
#   разброс (σ)  : 724 руб.
#   IQR 25–75%   : 2,302 — 3,322 руб.
# ──────────────────────────────────────────────────
